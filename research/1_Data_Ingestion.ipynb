# %%
import os
# %pwd #shows project working directory......
# Out:
# 'c:\\Users\\siddh\\Desktop\\Study Material\\Data Science\\0.Projects.py\\5.Poultry Disease Detection System\\Poultry-Diseases-Detection\\research'

# %%
os.chdir("../")
# %pwd
# Out:
# 'c:\\Users\\siddh\\Desktop\\Study Material\\Data Science\\0.Projects.py\\5.Poultry Disease Detection System'

# %%
from src.PoultryDiseasesCNN.Poultry_Logger import setup_logger
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.PoultryDiseasesCNN.Poultry_Logger import setup_logger
#
# ModuleNotFoundError: No module named 'src'

# %%
from src.PoultryDiseasesCNN.constants import *
from src.PoultryDiseasesCNN.utils.common import read_yaml, create_directories
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.PoultryDiseasesCNN.constants import *
#       2 from src.PoultryDiseasesCNN.utils.common import read_yaml, create_directories
#
# ModuleNotFoundError: No module named 'src'

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 class ConfigurationManager:
#       2     def __init__(
#       3         self,
#       4         config_filepath = CONFIG_FILE_PATH,
#       5         params_filepath = PARAMS_FILE_PATH):
#       7         self.config = read_yaml(config_filepath)
#
# Cell In[33], line 4, in ConfigurationManager()
#       1 class ConfigurationManager:
#       2     def __init__(
#       3         self,
# ----> 4         config_filepath = CONFIG_FILE_PATH,
#       5         params_filepath = PARAMS_FILE_PATH):
#       7         self.config = read_yaml(config_filepath)
#       8         self.params = read_yaml(params_filepath)
#
# NameError: name 'CONFIG_FILE_PATH' is not defined
